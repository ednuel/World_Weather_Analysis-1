# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config_gmaps import g_key

# %%
# Generate 1,500 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=1500)
lngs = np.random.uniform(-180.0,180.0,size=1500)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['kalmunai', 'san jeronimo', 'bambous virieux', 'atuona', 'hobart', 'vaini', 'victoria', 'albany', 'petropavlovsk-kamchatskiy', 'punta arenas'] Generate 619

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description,
                        'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kalmunai
# Processing Record 2 of Set 1 | san jeronimo
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | agadir
# Processing Record 12 of Set 1 | kruisfontein
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | palu
# Processing Record 15 of Set 1 | coihaique
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | deputatskiy
# Processing Record 18 of Set 1 | phuket
# Processing Record 19 of Set 1 | barcelos
# Processing Record 20 of Set 1 | maunabo
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | zeya
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | severo-kurilsk
# Processing Record 27 of Set 1 | college
# Processing Record 28 of Set 1 | mahibadhoo
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | souillac
# Processing Record 31 of Set 1 | luwuk
# Processing Record 32 of Set 1 | cap malheureux
# Processing Record 33 of Set 1 | la gomera
# Processing Record 34 of Set 1 | grindavik
# Processing Record 35 of Set 1 | angangxi
# City not found. Skipping...
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | houston
# Processing Record 38 of Set 1 | aktau
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | odesskoye
# Processing Record 41 of Set 1 | sioux lookout
# Processing Record 42 of Set 1 | mananjary
# Processing Record 43 of Set 1 | kandrian
# Processing Record 44 of Set 1 | zhigalovo
# Processing Record 45 of Set 1 | vardo
# Processing Record 46 of Set 1 | osmaniye
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | marv dasht
# City not found. Skipping...
# Processing Record 49 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 1 | saskylakh
# Processing Record 1 of Set 2 | yialos
# City not found. Skipping...
# Processing Record 2 of Set 2 | hasaki
# Processing Record 3 of Set 2 | richards bay
# Processing Record 4 of Set 2 | ibirite
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | fortuna
# Processing Record 8 of Set 2 | columbus
# Processing Record 9 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 2 | rikitea
# Processing Record 11 of Set 2 | iqaluit
# Processing Record 12 of Set 2 | comodoro rivadavia
# Processing Record 13 of Set 2 | macusani
# Processing Record 14 of Set 2 | talaja
# Processing Record 15 of Set 2 | bengkulu
# City not found. Skipping...
# Processing Record 16 of Set 2 | aden
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | sur
# Processing Record 19 of Set 2 | olafsvik
# City not found. Skipping...
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | gumdag
# Processing Record 22 of Set 2 | caravelas
# Processing Record 23 of Set 2 | nguru
# Processing Record 24 of Set 2 | neiafu
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | nishihara
# Processing Record 28 of Set 2 | cidreira
# Processing Record 29 of Set 2 | taunggyi
# Processing Record 30 of Set 2 | neyvo-shaytanskiy
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | methven
# Processing Record 33 of Set 2 | luderitz
# Processing Record 34 of Set 2 | kwinana
# Processing Record 35 of Set 2 | slyudyanka
# Processing Record 36 of Set 2 | the valley
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | bonthe
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | upernavik
# Processing Record 41 of Set 2 | bowmore
# Processing Record 42 of Set 2 | ancud
# Processing Record 43 of Set 2 | katobu
# Processing Record 44 of Set 2 | whitehorse
# Processing Record 45 of Set 2 | epitalion
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | tuatapere
# Processing Record 48 of Set 2 | taperoa
# Processing Record 49 of Set 2 | shenjiamen
# Processing Record 50 of Set 2 | alofi
# Processing Record 1 of Set 3 | nanortalik
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | xining
# Processing Record 4 of Set 3 | farmington
# Processing Record 5 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 6 of Set 3 | cayenne
# Processing Record 7 of Set 3 | brae
# Processing Record 8 of Set 3 | dali
# Processing Record 9 of Set 3 | terney
# Processing Record 10 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 3 | havre
# Processing Record 12 of Set 3 | valentin gomez farias
# Processing Record 13 of Set 3 | kudahuvadhoo
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | faya
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | bud
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | mount gambier
# Processing Record 20 of Set 3 | kenora
# Processing Record 21 of Set 3 | moose factory
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | kavaratti
# Processing Record 24 of Set 3 | mount isa
# Processing Record 25 of Set 3 | mayskiy
# Processing Record 26 of Set 3 | serrana
# Processing Record 27 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 3 | yellowknife
# Processing Record 29 of Set 3 | rabo de peixe
# Processing Record 30 of Set 3 | huangnihe
# Processing Record 31 of Set 3 | mogadishu
# Processing Record 32 of Set 3 | linqiong
# Processing Record 33 of Set 3 | komsomolskiy
# Processing Record 34 of Set 3 | saldanha
# Processing Record 35 of Set 3 | port-gentil
# Processing Record 36 of Set 3 | esperance
# Processing Record 37 of Set 3 | mehamn
# Processing Record 38 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 39 of Set 3 | lasa
# Processing Record 40 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 41 of Set 3 | chicama
# Processing Record 42 of Set 3 | bethel
# Processing Record 43 of Set 3 | mikun
# Processing Record 44 of Set 3 | sakakah
# City not found. Skipping...
# Processing Record 45 of Set 3 | walvis bay
# Processing Record 46 of Set 3 | nikolskoye
# Processing Record 47 of Set 3 | obo
# Processing Record 48 of Set 3 | ponta do sol
# Processing Record 49 of Set 3 | kavieng
# Processing Record 50 of Set 3 | pangnirtung
# Processing Record 1 of Set 4 | port hardy
# Processing Record 2 of Set 4 | mar del plata
# Processing Record 3 of Set 4 | qaanaaq
# Processing Record 4 of Set 4 | sitka
# Processing Record 5 of Set 4 | bara
# Processing Record 6 of Set 4 | cape town
# Processing Record 7 of Set 4 | grand forks
# Processing Record 8 of Set 4 | constitucion
# Processing Record 9 of Set 4 | ilulissat
# Processing Record 10 of Set 4 | dauphin
# Processing Record 11 of Set 4 | dalvik
# Processing Record 12 of Set 4 | havoysund
# Processing Record 13 of Set 4 | yumen
# Processing Record 14 of Set 4 | novyye burasy
# Processing Record 15 of Set 4 | poum
# Processing Record 16 of Set 4 | mahebourg
# Processing Record 17 of Set 4 | geraldton
# Processing Record 18 of Set 4 | antalaha
# Processing Record 19 of Set 4 | ulladulla
# Processing Record 20 of Set 4 | tynda
# Processing Record 21 of Set 4 | price
# Processing Record 22 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 4 | beipiao
# Processing Record 24 of Set 4 | hlukhiv
# Processing Record 25 of Set 4 | torbay
# Processing Record 26 of Set 4 | banda aceh
# Processing Record 27 of Set 4 | cherskiy
# Processing Record 28 of Set 4 | sao joao da barra
# Processing Record 29 of Set 4 | katsuura
# Processing Record 30 of Set 4 | broome
# Processing Record 31 of Set 4 | orlik
# Processing Record 32 of Set 4 | bakchar
# Processing Record 33 of Set 4 | santa cruz do sul
# Processing Record 34 of Set 4 | pisco
# Processing Record 35 of Set 4 | huarmey
# Processing Record 36 of Set 4 | bafia
# Processing Record 37 of Set 4 | inirida
# Processing Record 38 of Set 4 | mandalgovi
# Processing Record 39 of Set 4 | henties bay
# Processing Record 40 of Set 4 | castro
# Processing Record 41 of Set 4 | guerrero negro
# Processing Record 42 of Set 4 | pareora
# Processing Record 43 of Set 4 | williamsburg
# Processing Record 44 of Set 4 | nakasongola
# Processing Record 45 of Set 4 | manali
# Processing Record 46 of Set 4 | kokopo
# Processing Record 47 of Set 4 | sterling
# Processing Record 48 of Set 4 | royan
# Processing Record 49 of Set 4 | port elizabeth
# Processing Record 50 of Set 4 | hovd
# Processing Record 1 of Set 5 | verkhnyaya maksakovka
# Processing Record 2 of Set 5 | udachnyy
# Processing Record 3 of Set 5 | artesia
# Processing Record 4 of Set 5 | mvuma
# Processing Record 5 of Set 5 | mayo
# Processing Record 6 of Set 5 | georgetown
# Processing Record 7 of Set 5 | puerto del rosario
# Processing Record 8 of Set 5 | ostrovnoy
# Processing Record 9 of Set 5 | finschhafen
# Processing Record 10 of Set 5 | saint-michel-des-saints
# Processing Record 11 of Set 5 | seoul
# Processing Record 12 of Set 5 | temiscaming
# Processing Record 13 of Set 5 | bhag
# Processing Record 14 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 5 | qasigiannguit
# Processing Record 16 of Set 5 | dryden
# Processing Record 17 of Set 5 | lompoc
# Processing Record 18 of Set 5 | quatre cocos
# Processing Record 19 of Set 5 | capissayan
# Processing Record 20 of Set 5 | nuuk
# Processing Record 21 of Set 5 | berlevag
# Processing Record 22 of Set 5 | nouadhibou
# Processing Record 23 of Set 5 | ponta delgada
# Processing Record 24 of Set 5 | faanui
# Processing Record 25 of Set 5 | saint-philippe
# Processing Record 26 of Set 5 | millinocket
# Processing Record 27 of Set 5 | ust-nera
# Processing Record 28 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 5 | westport
# Processing Record 30 of Set 5 | lorengau
# Processing Record 31 of Set 5 | port lincoln
# Processing Record 32 of Set 5 | shagonar
# Processing Record 33 of Set 5 | la tuque
# Processing Record 34 of Set 5 | verkhnetulomskiy
# Processing Record 35 of Set 5 | sistranda
# Processing Record 36 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 5 | ribeira grande
# Processing Record 38 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 5 | airai
# Processing Record 41 of Set 5 | tazmalt
# Processing Record 42 of Set 5 | astana
# Processing Record 43 of Set 5 | bubaque
# Processing Record 44 of Set 5 | vestmannaeyjar
# Processing Record 45 of Set 5 | new norfolk
# Processing Record 46 of Set 5 | mancora
# Processing Record 47 of Set 5 | itacarambi
# Processing Record 48 of Set 5 | termiz
# Processing Record 49 of Set 5 | argelia
# Processing Record 50 of Set 5 | methoni
# Processing Record 1 of Set 6 | iskateley
# Processing Record 2 of Set 6 | rock sound
# Processing Record 3 of Set 6 | hilo
# Processing Record 4 of Set 6 | goure
# Processing Record 5 of Set 6 | eureka
# Processing Record 6 of Set 6 | lebu
# Processing Record 7 of Set 6 | hobyo
# Processing Record 8 of Set 6 | tijara
# Processing Record 9 of Set 6 | ndele
# City not found. Skipping...
# Processing Record 10 of Set 6 | zhezkazgan
# Processing Record 11 of Set 6 | longyearbyen
# Processing Record 12 of Set 6 | saint-pierre
# Processing Record 13 of Set 6 | te anau
# Processing Record 14 of Set 6 | pundaguitan
# Processing Record 15 of Set 6 | panacan
# Processing Record 16 of Set 6 | santa cruz
# Processing Record 17 of Set 6 | vaasa
# Processing Record 18 of Set 6 | bethlehem
# Processing Record 19 of Set 6 | pout
# Processing Record 20 of Set 6 | zavodouspenskoye
# Processing Record 21 of Set 6 | namie
# Processing Record 22 of Set 6 | kudat
# Processing Record 23 of Set 6 | luau
# Processing Record 24 of Set 6 | gustrow
# Processing Record 25 of Set 6 | carnarvon
# Processing Record 26 of Set 6 | provideniya
# Processing Record 27 of Set 6 | santa rosa de cabal
# Processing Record 28 of Set 6 | kahului
# Processing Record 29 of Set 6 | aasiaat
# Processing Record 30 of Set 6 | guasdualito
# Processing Record 31 of Set 6 | codrington
# Processing Record 32 of Set 6 | jalor
# Processing Record 33 of Set 6 | lavrentiya
# Processing Record 34 of Set 6 | sakaiminato
# Processing Record 35 of Set 6 | sandpoint
# Processing Record 36 of Set 6 | morondava
# Processing Record 37 of Set 6 | porto santo
# City not found. Skipping...
# Processing Record 38 of Set 6 | yeppoon
# Processing Record 39 of Set 6 | naze
# Processing Record 40 of Set 6 | parrsboro
# Processing Record 41 of Set 6 | beringovskiy
# Processing Record 42 of Set 6 | tver
# Processing Record 43 of Set 6 | cuxhaven
# Processing Record 44 of Set 6 | pevek
# Processing Record 45 of Set 6 | veraval
# Processing Record 46 of Set 6 | metu
# Processing Record 47 of Set 6 | brenham
# Processing Record 48 of Set 6 | sinnamary
# Processing Record 49 of Set 6 | torquay
# Processing Record 50 of Set 6 | amla
# Processing Record 1 of Set 7 | trinidad
# Processing Record 2 of Set 7 | sovetskiy
# Processing Record 3 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 4 of Set 7 | jiazi
# Processing Record 5 of Set 7 | eganville
# Processing Record 6 of Set 7 | lisala
# Processing Record 7 of Set 7 | los llanos de aridane
# Processing Record 8 of Set 7 | imbituba
# Processing Record 9 of Set 7 | sambava
# Processing Record 10 of Set 7 | payette
# Processing Record 11 of Set 7 | buon me thuot
# City not found. Skipping...
# Processing Record 12 of Set 7 | clovis
# Processing Record 13 of Set 7 | nabire
# Processing Record 14 of Set 7 | gourcy
# Processing Record 15 of Set 7 | saquarema
# Processing Record 16 of Set 7 | bonavista
# Processing Record 17 of Set 7 | montepuez
# Processing Record 18 of Set 7 | cauquenes
# Processing Record 19 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 7 | maniitsoq
# Processing Record 21 of Set 7 | fayaoue
# Processing Record 22 of Set 7 | jumla
# Processing Record 23 of Set 7 | sorland
# Processing Record 24 of Set 7 | loralai
# Processing Record 25 of Set 7 | nemuro
# Processing Record 26 of Set 7 | ugoofaaru
# Processing Record 27 of Set 7 | coquimbo
# Processing Record 28 of Set 7 | sao filipe
# Processing Record 29 of Set 7 | laguna
# Processing Record 30 of Set 7 | salalah
# Processing Record 31 of Set 7 | valparaiso
# Processing Record 32 of Set 7 | saint-joseph
# Processing Record 33 of Set 7 | padang
# Processing Record 34 of Set 7 | muros
# Processing Record 35 of Set 7 | wangkui
# Processing Record 36 of Set 7 | kenai
# Processing Record 37 of Set 7 | tiksi
# Processing Record 38 of Set 7 | nalut
# Processing Record 39 of Set 7 | iquique
# Processing Record 40 of Set 7 | abu samrah
# Processing Record 41 of Set 7 | biak
# Processing Record 42 of Set 7 | manokwari
# Processing Record 43 of Set 7 | paamiut
# Processing Record 44 of Set 7 | presidencia roque saenz pena
# Processing Record 45 of Set 7 | saint george
# Processing Record 46 of Set 7 | oruro
# Processing Record 47 of Set 7 | qui nhon
# City not found. Skipping...
# Processing Record 48 of Set 7 | rawson
# Processing Record 49 of Set 7 | aksarka
# Processing Record 50 of Set 7 | dera din panah
# City not found. Skipping...
# Processing Record 1 of Set 8 | bambanglipuro
# Processing Record 2 of Set 8 | lagoa
# Processing Record 3 of Set 8 | hualmay
# Processing Record 4 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 8 | pitanga
# Processing Record 6 of Set 8 | labuhan
# Processing Record 7 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 8 | hofn
# Processing Record 9 of Set 8 | dukat
# Processing Record 10 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 8 | taywarah
# Processing Record 12 of Set 8 | camacha
# Processing Record 13 of Set 8 | ferme-neuve
# Processing Record 14 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 8 | atar
# Processing Record 16 of Set 8 | talnakh
# Processing Record 17 of Set 8 | chuy
# Processing Record 18 of Set 8 | baykit
# Processing Record 19 of Set 8 | dikson
# Processing Record 20 of Set 8 | coahuayana
# Processing Record 21 of Set 8 | trofors
# Processing Record 22 of Set 8 | adelaide
# Processing Record 23 of Set 8 | sawakin
# Processing Record 24 of Set 8 | musoma
# Processing Record 25 of Set 8 | boysun
# Processing Record 26 of Set 8 | kakuda
# Processing Record 27 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 8 | aksu
# Processing Record 29 of Set 8 | kieta
# Processing Record 30 of Set 8 | forestville
# Processing Record 31 of Set 8 | talara
# Processing Record 32 of Set 8 | hadimkoy
# City not found. Skipping...
# Processing Record 33 of Set 8 | coolum beach
# Processing Record 34 of Set 8 | sibolga
# Processing Record 35 of Set 8 | maiquetia
# Processing Record 36 of Set 8 | grand gaube
# Processing Record 37 of Set 8 | agua fria
# Processing Record 38 of Set 8 | kose
# Processing Record 39 of Set 8 | lamas
# Processing Record 40 of Set 8 | najran
# Processing Record 41 of Set 8 | burnie
# Processing Record 42 of Set 8 | phan thiet
# Processing Record 43 of Set 8 | murdochville
# Processing Record 44 of Set 8 | hadejia
# Processing Record 45 of Set 8 | puerto escondido
# Processing Record 46 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 47 of Set 8 | namatanai
# Processing Record 48 of Set 8 | villarrobledo
# Processing Record 49 of Set 8 | puerto cabezas
# Processing Record 50 of Set 8 | mapiri
# Processing Record 1 of Set 9 | ibarra
# Processing Record 2 of Set 9 | auki
# Processing Record 3 of Set 9 | nieves
# Processing Record 4 of Set 9 | ewa beach
# Processing Record 5 of Set 9 | petropavlovka
# Processing Record 6 of Set 9 | rincon
# Processing Record 7 of Set 9 | inuvik
# Processing Record 8 of Set 9 | clyde river
# Processing Record 9 of Set 9 | registro
# Processing Record 10 of Set 9 | norman wells
# Processing Record 11 of Set 9 | reforma
# Processing Record 12 of Set 9 | tokmak
# Processing Record 13 of Set 9 | marystown
# Processing Record 14 of Set 9 | pedro juan caballero
# Processing Record 15 of Set 9 | jalu
# Processing Record 16 of Set 9 | dunda
# Processing Record 17 of Set 9 | dunedin
# Processing Record 18 of Set 9 | coruripe
# Processing Record 19 of Set 9 | shelburne
# Processing Record 20 of Set 9 | bagdarin
# Processing Record 21 of Set 9 | baherden
# Processing Record 22 of Set 9 | capinopolis
# Processing Record 23 of Set 9 | bireun
# Processing Record 24 of Set 9 | chichica
# Processing Record 25 of Set 9 | saint-francois
# Processing Record 26 of Set 9 | avera
# Processing Record 27 of Set 9 | whyalla
# Processing Record 28 of Set 9 | araouane
# Processing Record 29 of Set 9 | vila franca do campo
# Processing Record 30 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 9 | camana
# City not found. Skipping...
# Processing Record 32 of Set 9 | penzance
# Processing Record 33 of Set 9 | tambura
# City not found. Skipping...
# Processing Record 34 of Set 9 | santiago
# Processing Record 35 of Set 9 | tarragona
# Processing Record 36 of Set 9 | vilyuysk
# Processing Record 37 of Set 9 | hervey bay
# Processing Record 38 of Set 9 | port-cartier
# Processing Record 39 of Set 9 | sampit
# Processing Record 40 of Set 9 | nome
# Processing Record 41 of Set 9 | kaitangata
# Processing Record 42 of Set 9 | bathsheba
# Processing Record 43 of Set 9 | ixtapa
# Processing Record 44 of Set 9 | yenagoa
# Processing Record 45 of Set 9 | champerico
# Processing Record 46 of Set 9 | iznik
# Processing Record 47 of Set 9 | tonstad
# Processing Record 48 of Set 9 | taltal
# Processing Record 49 of Set 9 | volnovakha
# Processing Record 50 of Set 9 | zonguldak
# Processing Record 1 of Set 10 | charters towers
# Processing Record 2 of Set 10 | kitimat
# Processing Record 3 of Set 10 | necochea
# Processing Record 4 of Set 10 | bijapur
# City not found. Skipping...
# Processing Record 5 of Set 10 | hami
# Processing Record 6 of Set 10 | hit
# Processing Record 7 of Set 10 | okandja
# City not found. Skipping...
# Processing Record 8 of Set 10 | emerald
# Processing Record 9 of Set 10 | prokopyevsk
# Processing Record 10 of Set 10 | uyuni
# Processing Record 11 of Set 10 | sept-iles
# Processing Record 12 of Set 10 | tezu
# Processing Record 13 of Set 10 | west wendover
# Processing Record 14 of Set 10 | kloulklubed
# Processing Record 15 of Set 10 | tikhvin
# Processing Record 16 of Set 10 | pacific grove
# Processing Record 17 of Set 10 | tomatlan
# Processing Record 18 of Set 10 | asau
# City not found. Skipping...
# Processing Record 19 of Set 10 | khani
# Processing Record 20 of Set 10 | san patricio
# Processing Record 21 of Set 10 | pingdingshan
# Processing Record 22 of Set 10 | novouzensk
# Processing Record 23 of Set 10 | nisia floresta
# Processing Record 24 of Set 10 | hoshcha
# Processing Record 25 of Set 10 | northam
# Processing Record 26 of Set 10 | wuning
# Processing Record 27 of Set 10 | portland
# Processing Record 28 of Set 10 | kuznechikha
# Processing Record 29 of Set 10 | at-bashi
# Processing Record 30 of Set 10 | cangucu
# Processing Record 31 of Set 10 | vagur
# Processing Record 32 of Set 10 | maumere
# Processing Record 33 of Set 10 | san pedro
# Processing Record 34 of Set 10 | cruzeiro do sul
# Processing Record 35 of Set 10 | bilma
# Processing Record 36 of Set 10 | muli
# Processing Record 37 of Set 10 | klaksvik
# Processing Record 38 of Set 10 | alyangula
# Processing Record 39 of Set 10 | ust-omchug
# Processing Record 40 of Set 10 | escuinapa
# City not found. Skipping...
# Processing Record 41 of Set 10 | uchana
# Processing Record 42 of Set 10 | cabo san lucas
# Processing Record 43 of Set 10 | corinth
# Processing Record 44 of Set 10 | macia
# Processing Record 45 of Set 10 | kayes
# Processing Record 46 of Set 10 | uporovo
# Processing Record 47 of Set 10 | husavik
# Processing Record 48 of Set 10 | mitu
# Processing Record 49 of Set 10 | praya
# Processing Record 50 of Set 10 | ahuimanu
# Processing Record 1 of Set 11 | caririacu
# Processing Record 2 of Set 11 | rio branco
# Processing Record 3 of Set 11 | mashhad
# Processing Record 4 of Set 11 | lianzhou
# Processing Record 5 of Set 11 | rio grande
# Processing Record 6 of Set 11 | pathein
# Processing Record 7 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 11 | flin flon
# Processing Record 9 of Set 11 | agadez
# Processing Record 10 of Set 11 | miraflores
# Processing Record 11 of Set 11 | kotka
# Processing Record 12 of Set 11 | villamontes
# Processing Record 13 of Set 11 | dhilwan
# Processing Record 14 of Set 11 | kaeo
# Processing Record 15 of Set 11 | moroni
# Processing Record 16 of Set 11 | korla
# City not found. Skipping...
# Processing Record 17 of Set 11 | katangli
# Processing Record 18 of Set 11 | olenegorsk
# Processing Record 19 of Set 11 | busembatia
# Processing Record 20 of Set 11 | launceston
# Processing Record 21 of Set 11 | irbeyskoye
# Processing Record 22 of Set 11 | duiwelskloof
# Processing Record 23 of Set 11 | olga
# Processing Record 24 of Set 11 | pekan
# Processing Record 25 of Set 11 | cockburn town
# Processing Record 26 of Set 11 | lakes entrance
# Processing Record 27 of Set 11 | cotonou
# Processing Record 28 of Set 11 | guatire
# Processing Record 29 of Set 11 | nynashamn
# Processing Record 30 of Set 11 | rio gallegos
# Processing Record 31 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 32 of Set 11 | yueyang
# Processing Record 33 of Set 11 | khandagayty
# Processing Record 34 of Set 11 | crotone
# Processing Record 35 of Set 11 | anar darreh
# City not found. Skipping...
# Processing Record 36 of Set 11 | omboue
# Processing Record 37 of Set 11 | wewak
# Processing Record 38 of Set 11 | kodiak
# Processing Record 39 of Set 11 | gdansk
# Processing Record 40 of Set 11 | maroantsetra
# Processing Record 41 of Set 11 | hay river
# Processing Record 42 of Set 11 | mantua
# Processing Record 43 of Set 11 | christchurch
# Processing Record 44 of Set 11 | fort nelson
# Processing Record 45 of Set 11 | jatiroto
# Processing Record 46 of Set 11 | narrabri
# Processing Record 47 of Set 11 | navadwip
# Processing Record 48 of Set 11 | sladkovo
# Processing Record 49 of Set 11 | dagana
# Processing Record 50 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 12 | nantucket
# Processing Record 2 of Set 12 | yerofey pavlovich
# Processing Record 3 of Set 12 | karaton
# Processing Record 4 of Set 12 | srednekolymsk
# Processing Record 5 of Set 12 | zaraza
# Processing Record 6 of Set 12 | ishigaki
# Processing Record 7 of Set 12 | ulety
# Processing Record 8 of Set 12 | ukiah
# Processing Record 9 of Set 12 | xiaoweizhai
# Processing Record 10 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 12 of Set 12 | saint-augustin
# Processing Record 13 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 14 of Set 12 | lincoln
# Processing Record 15 of Set 12 | rudbar
# City not found. Skipping...
# Processing Record 16 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 12 | dmitriyevka
# Processing Record 18 of Set 12 | halifax
# Processing Record 19 of Set 12 | batemans bay
# Processing Record 20 of Set 12 | port macquarie
# Processing Record 21 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 12 | shushenskoye
# Processing Record 23 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 12 | nikolayevsk-na-amure
# Processing Record 25 of Set 12 | waingapu
# Processing Record 26 of Set 12 | maragogi
# Processing Record 27 of Set 12 | pine bluff
# Processing Record 28 of Set 12 | qarchi gak
# Processing Record 29 of Set 12 | ahipara
# Processing Record 30 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 31 of Set 12 | waipawa
# Processing Record 32 of Set 12 | qingdao
# Processing Record 33 of Set 12 | sale
# Processing Record 34 of Set 12 | san policarpo
# Processing Record 35 of Set 12 | ajdabiya
# Processing Record 36 of Set 12 | huilong
# Processing Record 37 of Set 12 | haines junction
# Processing Record 38 of Set 12 | coroata
# Processing Record 39 of Set 12 | ambon
# Processing Record 40 of Set 12 | raga
# City not found. Skipping...
# Processing Record 41 of Set 12 | yartsevo
# Processing Record 42 of Set 12 | amur
# Processing Record 43 of Set 12 | fare
# Processing Record 44 of Set 12 | murovani kurylivtsi
# Processing Record 45 of Set 12 | vuktyl
# Processing Record 46 of Set 12 | quesnel
# Processing Record 47 of Set 12 | boa vista
# Processing Record 48 of Set 12 | soyo
# Processing Record 49 of Set 12 | lanzhou
# Processing Record 50 of Set 12 | reconquista
# Processing Record 1 of Set 13 | garowe
# Processing Record 2 of Set 13 | teknaf
# Processing Record 3 of Set 13 | meulaboh
# Processing Record 4 of Set 13 | vanimo
# Processing Record 5 of Set 13 | kikwit
# Processing Record 6 of Set 13 | yabrud
# Processing Record 7 of Set 13 | marzuq
# Processing Record 8 of Set 13 | buin
# Processing Record 9 of Set 13 | pontianak
# Processing Record 10 of Set 13 | krasnorechenskiy
# Processing Record 11 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 13 | noumea
# Processing Record 13 of Set 13 | marrakesh
# Processing Record 14 of Set 13 | yeniseysk
# Processing Record 15 of Set 13 | ler
# Processing Record 16 of Set 13 | prince george
# Processing Record 17 of Set 13 | grafton
# Processing Record 18 of Set 13 | merauke
# Processing Record 19 of Set 13 | hambantota
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 561

# %%
#Save the new DataFrame as a CSV file
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.to_csv(path_or_buf='Challenge_Results/WeatherPy_challenge.csv', index_label='City_ID')

# %% [markdown]
# # How many cities have recorded rainfall or snow?
# ## There are 56 cities recorded rainfall, and 28 cities snowing.

# %%
# How many cities have recorded rainfall?
raining_count = challenge_city_data_df.loc[(challenge_city_data_df['Rain inches (last 3 hrs)']!=0)].count()
raining_count
# Out:
# City                        56
# Country                     56
# Date                        56
# Lat                         56
# Lng                         56
# Max Temp                    56
# Humidity                    56
# Cloudiness                  56
# Wind Speed                  56
# Current Description         56
# Rain inches (last 3 hrs)    56
# Snow inches (last 3 hrs)    56
# dtype: int64

# %%
# How many cities have recorded snow?
snowing_count = challenge_city_data_df.loc[(challenge_city_data_df['Snow inches (last 3 hrs)']!=0)].count()
snowing_count
# Out:
# City                        28
# Country                     28
# Date                        28
# Lat                         28
# Lng                         28
# Max Temp                    28
# Humidity                    28
# Cloudiness                  28
# Wind Speed                  28
# Current Description         28
# Rain inches (last 3 hrs)    28
# Snow inches (last 3 hrs)    28
# dtype: int64
